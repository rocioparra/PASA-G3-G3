# %% [markdown]
# # Laboratorio de descenso por gradiente
# 22.46 Procesamiento adaptativo de señales aleatorias
#
# © 2019 Ariel S. Nowik, Rocío Parra

# %% [markdown]
# Este informe tiene como objetivo analizar el algoritmo de descenso por gradiente.

# %% [markdown]
# ## 1. Implementar el filtrado óptimo Wiener con descenso por gradiente en la plantilla `steepest_descent.py`. Prestar atención al formato de salida.

# %% [markdown]
# ## 2. Probar la función con los argumentos:
#
# $ R = \begin{bmatrix}
# 2 && 1 \\
# 1 && 2
# \end{bmatrix}, \quad
# p = \begin{bmatrix} 6 \\ 4 \end{bmatrix}, \quad
# \mu = 0.1, \quad N = 1000, \quad
# \mathrm{w}(0) = \begin{bmatrix} 0 \\ 0 \end{bmatrix}, \quad
# \sigma_d^2 = 20$
#
# Representar los coeficientes $\mathrm{w}_1$ y $\mathrm{w}_2$ en función del tiempo. Representar como referencia la solución del filtro óptimo Wiener correspondiente.

# %% [markdown]
# ## 3. Representar la curva de error J(n).

# %% [markdown]
# ## 4. Determinar los autovalores de R, y a partir de ellos determinar $\mu_{max}$. Para un valor de $\mu$ cercano a $\mu_{max}$ representar la evolución de los coeficientes $\mathrm{w}(t)$.

# %% [markdown]
# ## 5. Considerar el escenario de R y p variables en el tiempo. Explicar los beneficios del descenso por gradiente en comparación con el método de Wiener.

# %% [markdown]
# ## 6. El archivo `steepest_descent_test.py` filtra una señal de música $d(t)$ con un filtro Wiener obtenido por descenso por gradiente con diferentes valores de $\mu$. Analizar los gráficos generados. ¿Qué ocurre en el caso $\mu = 10^{-6}$?
